# %%
import pandas as pd
from pathlib import Path
import sys
import os

# %%
sys.path.append(os.path.abspath(".."))

from src.data_loader import load_data

# %%
df = load_data()

df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = load_data()
#       2
#       3 df.head()
#
# File ~\PythonProjects\prf-analytics\src\data_loader.py:29, in load_data(file_ids)
#      25 os.makedirs(raw_dir, exist_ok=True)
#      27 list_dfs = []
# ---> 29 for idx, file_id in enumerate(file_ids, start=1):
#      30     local_path = os.path.join(raw_dir, f"prf_data_{file_id}.csv")
#      32     if not os.path.exists(local_path):
#
# TypeError: 'NoneType' object is not iterable
